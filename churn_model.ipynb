# %% [markdown]
# ## Project Overview
# #### This is project about Customer Churn Prediction model. Basically we use 'Amazon Customer Dataset' as sample data.

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder, TargetEncoder

# %%
df = pd.read_csv('amazon_customer_dataset.csv')
df.head(3)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...

# %% [markdown]
# ## Data Investigation
# #### To create a Customer churn prediction model we need basically customer wise data. But in a primary investigation from df.head(3) identifier columns has data as a list format. We have to separate this data into a single customer data per row.

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
#  15  product_link         1465 non-null   object
# dtypes: object(16)
# memory usage: 183.3+ KB

# %%
df.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# #### There is no null values except 2 into rating_count.

# %%
cols_to_split = ['user_id', 'user_name', 'review_id', 'review_title', 'review_content']

for col in cols_to_split:
    df[col] = df[col].astype(str).str.split(',')

# df['__len__'] = df[cols_to_split[0]].apply(len)

# for col in cols_to_split[1:]:
#     df = df[df['__len__'] == df[col].apply(len)]

# %% [markdown]
# ## Data Spliting Process
# #### At first we separate the data from identifier column with comma. Then we tried length wise separation. Actually it works but we lost length mismatched data. Our target is to get a precise model, this kind of data loss can accelerate our model to towards biasness. So we will fixed mismatched data with blank string character. Then We will replace with NaN.

# %%
#check the column length and fill with blank space(padding function)
def pad_row(row):
    max_len = max(len(row[col]) for col in cols_to_split)
    for col in cols_to_split:
        diff = max_len - len(row[col])
        if diff > 0:
            row[col] = row[col] + ['']*diff
    return row

# %%
df_padded = df.apply(pad_row, axis=1)
expand_df = df_padded.explode(cols_to_split, ignore_index=True)
expand_df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 3  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹399
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1       ₹1,099                 64%    4.2       24,269
# 2       ₹1,099                 64%    4.2       24,269
# 3       ₹1,099                 64%    4.2       24,269
# 4       ₹1,099                 64%    4.2       24,269
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  High Compatibility : Compatible With iPhone 12...
# 2  High Compatibility : Compatible With iPhone 12...
# 3  High Compatibility : Compatible With iPhone 12...
# 4  High Compatibility : Compatible With iPhone 12...
#
#                         user_id       user_name       review_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q           Manav  R3HXWT0LRP0NMF
# 1  AHMY5CWJMMK5BJRBBSNLYT3ONILA    Adarsh gupta  R2AJM3LFTLZHFO
# 2  AHCTC6ULH4XB6YHDY6PCH2R772LQ         Sundeep    R6AQJGUP6P86
# 3  AGYHHIERNXKA6P5T7CZLXKVPT7IQ  S.Sayeed Ahmed  R1KD19VHEDV0OR
# 4  AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q  jaspreet singh  R3C02RMYQMK6FC
#
#               review_title                                     review_content  \
# 0                Satisfied     Looks durable Charging is fine tooNo complains
# 1  Charging is really fast                            Charging is really fast
# 2          Value for money                                      good product.
# 3           Product review               Till now satisfied with the quality.
# 4             Good quality  This is a good product . The charging speed is...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/W/WEBP_40237...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 2  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 3  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 4  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...

# %%
expand_df[expand_df['review_id'] == 'R3HXWT0LRP0NMF']
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 637   B07JW1Y6XV  Wayona Nylon Braided 3A Lightning to USB A Syn...
# 1215  B07LGT55SJ  Wayona Usb Nylon Braided Data Sync And Chargin...
# 1428  B07JH1C41D  Wayona Nylon Braided (2 Pack) Lightning Fast U...
# 1638  B07JGDB5M1  Wayona Nylon Braided 2M / 6Ft Fast Charge Usb ...
# 3220  B07JH1CBGW  Wayona Nylon Braided Usb Syncing And Charging ...
# 5444  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 9706  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# 637   Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1215  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1428  Computers&Accessories|Accessories&Peripherals|...             ₹649
# 1638  Computers&Accessories|Accessories&Peripherals|...             ₹449
# 3220  Computers&Accessories|Accessories&Peripherals|...             ₹649
# 5444  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 9706  Computers&Accessories|Accessories&Peripherals|...             ₹399
#
#      actual_price discount_percentage rating rating_count  \
# 0          ₹1,099                 64%    4.2       24,269
# 637        ₹1,099                 64%    4.2       24,269
# 1215       ₹1,099                 64%    4.2       24,269
# 1428       ₹1,999                 68%    4.2       24,269
# 1638       ₹1,299                 65%    4.2       24,269
# 3220       ₹1,999                 68%    4.2       24,269
# 5444       ₹1,099                 64%    4.2       24,270
# 9706       ₹1,099                 64%    4.2       24,269
#
#                                           about_product  \
# 0     High Compatibility : Compatible With iPhone 12...
# 637   [High Compatibility] : iPhone X/XsMax/Xr ,iPho...
# 1215  [High Compatibility] : Compatible For iPhone X...
# 1428  [High Compatibility] : iPhone X/XsMax/Xr ,iPho...
# 1638  [High Compatibility] : Phone X/XsMax/Xr ,Phone...
# 3220  [High Compatibility] : iPhone X/XsMax/Xr ,iPho...
# 5444  High Compatibility : Compatible With iPhone 12...
# 9706  High Compatibility : Compatible With iPhone 12...
#
#                            user_id user_name       review_id review_title  \
# 0     AG3D6O4STAQKAY2UVGEUV46KN35Q     Manav  R3HXWT0LRP0NMF    Satisfied
# 637   AG3D6O4STAQKAY2UVGEUV46KN35Q     Manav  R3HXWT0LRP0NMF    Satisfied
# 1215  AG3D6O4STAQKAY2UVGEUV46KN35Q     Manav  R3HXWT0LRP0NMF    Satisfied
# 1428  AG3D6O4STAQKAY2UVGEUV46KN35Q     Manav  R3HXWT0LRP0NMF    Satisfied
# 1638  AG3D6O4STAQKAY2UVGEUV46KN35Q     Manav  R3HXWT0LRP0NMF    Satisfied
# 3220  AG3D6O4STAQKAY2UVGEUV46KN35Q     Manav  R3HXWT0LRP0NMF    Satisfied
# 5444  AG3D6O4STAQKAY2UVGEUV46KN35Q     Manav  R3HXWT0LRP0NMF    Satisfied
# 9706  AG3D6O4STAQKAY2UVGEUV46KN35Q     Manav  R3HXWT0LRP0NMF    Satisfied
#
#                                       review_content  \
# 0     Looks durable Charging is fine tooNo complains
# 637   Looks durable Charging is fine tooNo complains
# 1215  Looks durable Charging is fine tooNo complains
# 1428  Looks durable Charging is fine tooNo complains
# 1638  Looks durable Charging is fine tooNo complains
# 3220  Looks durable Charging is fine tooNo complains
# 5444  Looks durable Charging is fine tooNo complains
# 9706  Looks durable Charging is fine tooNo complains
#
#                                                img_link  \
# 0     https://m.media-amazon.com/images/W/WEBP_40237...
# 637   https://m.media-amazon.com/images/W/WEBP_40237...
# 1215  https://m.media-amazon.com/images/W/WEBP_40237...
# 1428  https://m.media-amazon.com/images/I/412fvb7k2F...
# 1638  https://m.media-amazon.com/images/W/WEBP_40237...
# 3220  https://m.media-amazon.com/images/I/41eHLj-wfG...
# 5444  https://m.media-amazon.com/images/I/51UsScvHQN...
# 9706  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 0     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 637   https://www.amazon.in/Wayona-Braided-WN3LB1-Sy...
# 1215  https://www.amazon.in/Wayona-Braided-Syncing-C...
# 1428  https://www.amazon.in/Wayona-Braided-WN3LG2-Sy...
# 1638  https://www.amazon.in/Wayona-Braided-WN6LG1-Sy...
# 3220  https://www.amazon.in/Wayona-Braided-WN3LB2-Sy...
# 5444  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 9706  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...

# %%
expand_df.shape
# Out:
# (21968, 16)

# %% [markdown]
# #### After separation of data, we can see each row is specifically contains data for each customer. So the row size increased and we can use further process now.

# %%
expand_df = expand_df.replace('', np.nan)

info_cols = ['user_id', 'user_name', 'review_id']

expand_df = expand_df.dropna(subset=info_cols, how='all')

# %%
expand_df.isna().sum().sum()
# Out:
# np.int64(285)

# %% [markdown]
# ## Fill data with info from identifier columns
# #### As we can see, we dropped only those data where all our identifier columns are missing.
# #### why? Because if there is no information in any column of the identifier column, there will be no matching data to fill the empty cells.

# %%
def fill_user_id(df):

    for idx, row in df[df['user_id'].isna()].iterrows():
        #match with user_name
        if pd.notna(row['user_name']):
            match = df[df['user_name'] == row['user_name']]['user_id'].dropna()
            if len(match)>0:
                df.at[idx, 'user_id'] = match.iloc[0]
        
        #match with review_id
        if pd.notna(row['review_id']):
            match = df[df['review_id'] == row['review_id']]['user_id'].dropna()
            if len(match)>0:
                df.at[idx, 'user_id'] = match.iloc[0]
    return df


def fill_user_name(df):

    for idx, row in df[df['user_name'].isna()].iterrows():
        #match with user_id
        if pd.notna(row['user_id']):
            match = df[df['user_id'] == row['user_id']]['user_name'].dropna()
            if len(match)>0:
                df.at[idx, 'user_name'] = match.iloc[0]

        if pd.notna(row['review_id']):
            match = df[df['review_id'] == row['review_id']]['user_name'].dropna()
            if len(match)>0:
                df.at[idx, 'user_name'] = match.iloc[0]
    return df


def fill_review_id(df):

    for idx, row in df[df['review_id'].isna()].iterrows():

        #match with user_id
        if pd.notna(row['user_id']):
            match = df[df['user_id'] == row['user_id']]['review_id'].dropna()
            if len(match)>0:
                df.at[idx, 'review_id'] = match.iloc[0]

        #match with user_name
        if pd.notna(row['user_name']):
            match = df[df['user_name'] == row['user_name']]['review_id'].dropna()
            if len(match)>0:
                df.at[idx, 'review_id'] = match.iloc[0]
    return df

# %% [markdown]
# ## Smart Fill
# #### Now if we think our previous explanations we recursively use a word 'Identifier'. What does it means? Here is hide our filling methods. We will match and fill in the information in the other identifier columns.
# #### You can see above we create the filling fuction.

# %%
expand_df = fill_user_id(expand_df)
expand_df = fill_user_name(expand_df)
expand_df = fill_review_id(expand_df)

# %%
#null contain rows
expand_df[expand_df.isna().any(axis=1)]
# Out:
#        product_id                                       product_name  \
# 71     B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# 191    B083342NKJ  MI Braided USB Type-C Cable for Charging Adapt...
# 193    B083342NKJ  MI Braided USB Type-C Cable for Charging Adapt...
# 223    B08WRBG3XW  boAt Type C A325 Tangle-free, Sturdy Type C Ca...
# 369    B094JNXNPV  Ambrane Unbreakable 3 in 1 Fast Charging Braid...
# ...           ...                                                ...
# 21862  B08ZXZ362Z  akiara - Makes life easy Mini Sewing Machine f...
# 21867  B08ZXZ362Z  akiara - Makes life easy Mini Sewing Machine f...
# 21868  B00GHL8VP2  USHA 1212 PTC with Adjustable Thermostat Fan H...
# 21877  B0B9JZW1SQ  4 in 1 Handheld Electric Vegetable Cutter Set,...
# 21949  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
#
#                                                 category discounted_price  \
# 71     Computers&Accessories|Accessories&Peripherals|...             ₹149
# 191    Computers&Accessories|Accessories&Peripherals|...             ₹349
# 193    Computers&Accessories|Accessories&Peripherals|...             ₹349
# 223    Computers&Accessories|Accessories&Peripherals|...             ₹199
# 369    Computers&Accessories|Accessories&Peripherals|...             ₹299
# ...                                                  ...              ...
# 21862  Home&Kitchen|Kitchen&HomeAppliances|SewingMach...           ₹1,563
# 21867  Home&Kitchen|Kitchen&HomeAppliances|SewingMach...           ₹1,563
# 21868  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...        ₹3,487.77
# 21877  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...             ₹498
# 21949  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
#
#       actual_price discount_percentage rating rating_count  \
# 71          ₹1,000                 85%    3.9       24,871
# 191           ₹399                 13%    4.4       18,757
# 193           ₹399                 13%    4.4       18,757
# 223           ₹499                 60%    4.1       13,045
# 369           ₹399                 25%    4.0        2,766
# ...            ...                 ...    ...          ...
# 21862       ₹3,098                 50%    3.5        2,283
# 21867       ₹3,098                 50%    3.5        2,283
# 21868       ₹4,990                 30%    4.1        1,127
# 21877       ₹1,200                 59%    3.2          113
# 21949       ₹1,890                 26%      4        8,031
#
#                                            about_product  \
# 71     Fast Charging & Data Sync: Solero TB301 Type-C...
# 191    1M Long Cable. Usb 2.0 (Type A)|Toughened Join...
# 193    1M Long Cable. Usb 2.0 (Type A)|Toughened Join...
# 223    Type C A 325 Cable Is Designed With A Perfect ...
# 369    Blazing Charging - All combined 3 in 1 cable s...
# ...                                                  ...
# 21862  PORTABLE MINI SEWING MACHINE with threads and ...
# 21867  PORTABLE MINI SEWING MACHINE with threads and ...
# 21868  Meant for Spot Heating|Room Size: Upto 15 sq f...
# 21877  { 4 in 1 multi-function Electric Vegetable Cut...
# 21949  Fan sweep area: 230 MM ; Noise level: (40 - 45...
#
#                             user_id          user_name       review_id  \
# 71     AHFAAPSY2MJ5HYOU2VQDJ7AQY4NQ       Ajaybabu.O.M  R18MP1KLUE18PC
# 191    AHICHCW6EC3BNV2IDAEAJPBG4HZQ             Deepak  R1ZBD2ZB2ZYEWX
# 193    AGEOQQHGNELZNEUKJAJUA7NTPBLA             Rakesh  R1115HIQP3BKKJ
# 223    AGXRGH7DLS3RVFS5KWU4PGR3H3GQ     Gursewak Singh  R3VIKEVJ5DBF5G
# 369    AEO5NTPVZBDP7EHO2NOJ3Q6QPN3A                  C  R1M0NVGZXK8NGO
# ...                             ...                ...             ...
# 21862  AHX4KZVASMGQQOST4T2RAQUZTLCA        Kirti Gupta  R32BCA8W6W1KIF
# 21867  AHX47N6TUNADPXMMQKVASVBNIHJA  krishna chaudhari  R39210FVK81Z0W
# 21868  AECFYIUCHSZXDLACTYPEUSM5DIKA        Manoj Kumar  R1T19FVDX8Z7T2
# 21877  AFCTMQKPVJI6Y2JPIGDKRKIAV43A             Ashish  R3N2A5DV7IPG6R
# 21949  AG74HALEHHRAVFNXFHBM75RWZD6Q        ASHISHGAJBE  R223OFAZGIK4X7
#
#                                review_title                 review_content  \
# 71                                      NaN                            NaN
# 191                I really liked this one.                            NaN
# 193                                     NaN  Best data cable charging fast
# 223    Good Quality but less Power Delivery                            NaN
# 369                                  Sturdy                            NaN
# ...                                     ...                            ...
# 21862   Good for beginners or minor repairs                            NaN
# 21867                          Good product                            NaN
# 21868                   I like this product                            NaN
# 21877    Cutter speed and power is very low                            NaN
# 21949                          Old is gold.                            NaN
#
#                                                 img_link  \
# 71     https://m.media-amazon.com/images/I/31wOPjcSxl...
# 191    https://m.media-amazon.com/images/W/WEBP_40237...
# 193    https://m.media-amazon.com/images/W/WEBP_40237...
# 223    https://m.media-amazon.com/images/W/WEBP_40237...
# 369    https://m.media-amazon.com/images/W/WEBP_40237...
# ...                                                  ...
# 21862  https://m.media-amazon.com/images/W/WEBP_40237...
# 21867  https://m.media-amazon.com/images/W/WEBP_40237...
# 21868  https://m.media-amazon.com/images/W/WEBP_40237...
# 21877  https://m.media-amazon.com/images/W/WEBP_40237...
# 21949  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                             product_link
# 71     https://www.amazon.in/Solero-TB301-Charging-48...
# 191    https://www.amazon.in/Mi-Braided-USB-Type-C-Ca...
# 193    https://www.amazon.in/Mi-Braided-USB-Type-C-Ca...
# 223    https://www.amazon.in/boAt-A325-Tangle-Free-Ch...
# 369    https://www.amazon.in/Ambrane-Unbreakable-Char...
# ...                                                  ...
# 21862  https://www.amazon.in/akiara-Tailoring-Stitchi...
# 21867  https://www.amazon.in/akiara-Tailoring-Stitchi...
# 21868  https://www.amazon.in/Usha-1212-PTC-Adjustable...
# 21877  https://www.amazon.in/Handheld-Electric-Vegeta...
# 21949  https://www.amazon.in/Havells-Ventilair-230mm-...
#
# [253 rows x 16 columns]

# %%
#null contain columns
expand_df.isna().sum()
# Out:
# product_id               0
# product_name             0
# category                 0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   0
# rating_count             2
# about_product            0
# user_id                  3
# user_name                1
# review_id                3
# review_title            25
# review_content         233
# img_link                 0
# product_link             0
# dtype: int64

# %%
expand_df[expand_df[info_cols].isna().any(axis=1)]
# Out:
#        product_id                                       product_name  \
# 1063   B0B9XN9S3W  Acer 80 cm (32 inches) N Series HD Ready TV AR...
# 1656   B0981XSZJ7  CROSSVOLT Compatible Dash/Warp Data Sync Fast ...
# 14883  B07T9FV9YP  Redgear Cloak Wired RGB Wired Over Ear Gaming ...
# 17155  B07MKMFKPG   Bosch Pro 1000W Mixer Grinder MGM8842MIN - Black
#
#                                                 category discounted_price  \
# 1063   Electronics|HomeTheater,TV&Video|Televisions|S...           ₹7,999
# 1656   Computers&Accessories|Accessories&Peripherals|...             ₹299
# 14883  Computers&Accessories|Accessories&Peripherals|...             ₹749
# 17155  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹6,999
#
#       actual_price discount_percentage rating rating_count  \
# 1063       ₹14,990                 47%    4.3          457
# 1656          ₹999                 70%    4.3          766
# 14883       ₹1,799                 58%    4.0       13,199
# 17155      ₹10,590                 34%    4.4       11,499
#
#                                            about_product  \
# 1063   Resolution: HD Ready (1366 x 768) | Refresh Ra...
# 1656   Compatible for oneplus 9 PRO/9/9R/8T/8PRO/7PRO...
# 14883  Sound Quality: Redgear Cloak comes equipped wi...
# 17155  Uniquely designed blunt PoundingBlade with thi...
#
#                             user_id           user_name       review_id  \
# 1063                            NaN       T Karthikeyan             NaN
# 1656                            NaN  Prakash Waghchaure             NaN
# 14883                           NaN                  CM             NaN
# 17155  AGOEYCHBYOAN53ZBHUMCS5GUSVTQ                 NaN  R3NTM54N8T1YCL
#
#                   review_title  \
# 1063                       NaN
# 1656                       NaN
# 14883                      NaN
# 17155  Powerfull mixer grinder
#
#                                           review_content  \
# 1063    not that bad. If you want to buy a 32'' TV at...
# 1656   Product is Suitable for my Oneplus Nord workin...
# 14883   i also use the windows sonic for headphones a...
# 17155                                    Chana dal paste
#
#                                                 img_link  \
# 1063   https://m.media-amazon.com/images/I/51FicDnawa...
# 1656   https://m.media-amazon.com/images/W/WEBP_40237...
# 14883  https://m.media-amazon.com/images/W/WEBP_40237...
# 17155  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                             product_link
# 1063   https://www.amazon.in/Acer-inches-Ready-AR32NS...
# 1656   https://www.amazon.in/CROSSVOLT-Compatible-Cha...
# 14883  https://www.amazon.in/Redgear-Cloak-Gaming-Hea...
# 17155  https://www.amazon.in/Bosch-TrueMixx-Pro-Grind...

# %%
expand_df[info_cols] = expand_df[info_cols].fillna('Unknown')

# %%
expand_df.isna().sum()
# Out:
# product_id               0
# product_name             0
# category                 0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   0
# rating_count             2
# about_product            0
# user_id                  0
# user_name                0
# review_id                0
# review_title            25
# review_content         233
# img_link                 0
# product_link             0
# dtype: int64

# %%
for idx, row in expand_df[expand_df['rating_count'].isna()].iterrows():
    if pd.notna(row['product_id']):
        match = expand_df[expand_df['product_id'] == row['product_id']]['rating_count'].dropna()
        if len(match)>0:
            expand_df.at[idx, 'rating_count'] = match.iloc[0]

# %%
expand_df[expand_df['rating_count'].isna()]
# Out:
#       product_id                                       product_name  \
# 4058  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 4547  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                                category discounted_price  \
# 4058  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 4547  Computers&Accessories|Accessories&Peripherals|...             ₹249
#
#      actual_price discount_percentage rating rating_count  \
# 4058         ₹999                 80%    3.0          NaN
# 4547         ₹999                 75%    5.0          NaN
#
#                                           about_product  \
# 4058  USB C to C Cable: This cable has type C connec...
# 4547  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                            user_id    user_name      review_id  \
# 4058  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# 4547  AGJC5O5H5BBXWUV7WRIEIOOR3TVQ  Abdul Gafur  RQXD5SAMMPC6L
#
#                                       review_title  \
# 4058  The cable works but is not 65W as advertised
# 4547                               Awesome Product
#
#                                          review_content  \
# 4058  I have a pd supported car charger and I bought...
# 4547  Quick delivery.Awesome ProductPacking was good...
#
#                                                img_link  \
# 4058  https://m.media-amazon.com/images/W/WEBP_40237...
# 4547  https://m.media-amazon.com/images/I/31-q0xhaTA...
#
#                                            product_link
# 4058  https://www.amazon.in/Amazon-Brand-Charging-Su...
# 4547  https://www.amazon.in/REDTECH-Lightning-Certif...

# %%
expand_df[expand_df['product_id'] == 'B0B94JPY2N']
# Out:
#       product_id                                       product_name  \
# 4058  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
#
#                                                category discounted_price  \
# 4058  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#      actual_price discount_percentage rating rating_count  \
# 4058         ₹999                 80%    3.0          NaN
#
#                                           about_product  \
# 4058  USB C to C Cable: This cable has type C connec...
#
#                            user_id user_name     review_id  \
# 4058  AE7CFHY23VAJT2FI4NZKKP6GS2UQ    Pranav  RUB7U91HVZ30
#
#                                       review_title  \
# 4058  The cable works but is not 65W as advertised
#
#                                          review_content  \
# 4058  I have a pd supported car charger and I bought...
#
#                                                img_link  \
# 4058  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 4058  https://www.amazon.in/Amazon-Brand-Charging-Su...

# %%
expand_df[expand_df['product_id'] == 'B0BQRJ3C47']
# Out:
#       product_id                                       product_name  \
# 4547  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                                category discounted_price  \
# 4547  Computers&Accessories|Accessories&Peripherals|...             ₹249
#
#      actual_price discount_percentage rating rating_count  \
# 4547         ₹999                 75%    5.0          NaN
#
#                                           about_product  \
# 4547  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                            user_id    user_name      review_id  \
# 4547  AGJC5O5H5BBXWUV7WRIEIOOR3TVQ  Abdul Gafur  RQXD5SAMMPC6L
#
#          review_title                                     review_content  \
# 4547  Awesome Product  Quick delivery.Awesome ProductPacking was good...
#
#                                                img_link  \
# 4547  https://m.media-amazon.com/images/I/31-q0xhaTA...
#
#                                            product_link
# 4547  https://www.amazon.in/REDTECH-Lightning-Certif...

# %%
expand_df[expand_df.isna().any(axis=1)]
# Out:
#        product_id                                       product_name  \
# 71     B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# 191    B083342NKJ  MI Braided USB Type-C Cable for Charging Adapt...
# 193    B083342NKJ  MI Braided USB Type-C Cable for Charging Adapt...
# 223    B08WRBG3XW  boAt Type C A325 Tangle-free, Sturdy Type C Ca...
# 369    B094JNXNPV  Ambrane Unbreakable 3 in 1 Fast Charging Braid...
# ...           ...                                                ...
# 21862  B08ZXZ362Z  akiara - Makes life easy Mini Sewing Machine f...
# 21867  B08ZXZ362Z  akiara - Makes life easy Mini Sewing Machine f...
# 21868  B00GHL8VP2  USHA 1212 PTC with Adjustable Thermostat Fan H...
# 21877  B0B9JZW1SQ  4 in 1 Handheld Electric Vegetable Cutter Set,...
# 21949  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
#
#                                                 category discounted_price  \
# 71     Computers&Accessories|Accessories&Peripherals|...             ₹149
# 191    Computers&Accessories|Accessories&Peripherals|...             ₹349
# 193    Computers&Accessories|Accessories&Peripherals|...             ₹349
# 223    Computers&Accessories|Accessories&Peripherals|...             ₹199
# 369    Computers&Accessories|Accessories&Peripherals|...             ₹299
# ...                                                  ...              ...
# 21862  Home&Kitchen|Kitchen&HomeAppliances|SewingMach...           ₹1,563
# 21867  Home&Kitchen|Kitchen&HomeAppliances|SewingMach...           ₹1,563
# 21868  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...        ₹3,487.77
# 21877  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...             ₹498
# 21949  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
#
#       actual_price discount_percentage rating rating_count  \
# 71          ₹1,000                 85%    3.9       24,871
# 191           ₹399                 13%    4.4       18,757
# 193           ₹399                 13%    4.4       18,757
# 223           ₹499                 60%    4.1       13,045
# 369           ₹399                 25%    4.0        2,766
# ...            ...                 ...    ...          ...
# 21862       ₹3,098                 50%    3.5        2,283
# 21867       ₹3,098                 50%    3.5        2,283
# 21868       ₹4,990                 30%    4.1        1,127
# 21877       ₹1,200                 59%    3.2          113
# 21949       ₹1,890                 26%      4        8,031
#
#                                            about_product  \
# 71     Fast Charging & Data Sync: Solero TB301 Type-C...
# 191    1M Long Cable. Usb 2.0 (Type A)|Toughened Join...
# 193    1M Long Cable. Usb 2.0 (Type A)|Toughened Join...
# 223    Type C A 325 Cable Is Designed With A Perfect ...
# 369    Blazing Charging - All combined 3 in 1 cable s...
# ...                                                  ...
# 21862  PORTABLE MINI SEWING MACHINE with threads and ...
# 21867  PORTABLE MINI SEWING MACHINE with threads and ...
# 21868  Meant for Spot Heating|Room Size: Upto 15 sq f...
# 21877  { 4 in 1 multi-function Electric Vegetable Cut...
# 21949  Fan sweep area: 230 MM ; Noise level: (40 - 45...
#
#                             user_id          user_name       review_id  \
# 71     AHFAAPSY2MJ5HYOU2VQDJ7AQY4NQ       Ajaybabu.O.M  R18MP1KLUE18PC
# 191    AHICHCW6EC3BNV2IDAEAJPBG4HZQ             Deepak  R1ZBD2ZB2ZYEWX
# 193    AGEOQQHGNELZNEUKJAJUA7NTPBLA             Rakesh  R1115HIQP3BKKJ
# 223    AGXRGH7DLS3RVFS5KWU4PGR3H3GQ     Gursewak Singh  R3VIKEVJ5DBF5G
# 369    AEO5NTPVZBDP7EHO2NOJ3Q6QPN3A                  C  R1M0NVGZXK8NGO
# ...                             ...                ...             ...
# 21862  AHX4KZVASMGQQOST4T2RAQUZTLCA        Kirti Gupta  R32BCA8W6W1KIF
# 21867  AHX47N6TUNADPXMMQKVASVBNIHJA  krishna chaudhari  R39210FVK81Z0W
# 21868  AECFYIUCHSZXDLACTYPEUSM5DIKA        Manoj Kumar  R1T19FVDX8Z7T2
# 21877  AFCTMQKPVJI6Y2JPIGDKRKIAV43A             Ashish  R3N2A5DV7IPG6R
# 21949  AG74HALEHHRAVFNXFHBM75RWZD6Q        ASHISHGAJBE  R223OFAZGIK4X7
#
#                                review_title                 review_content  \
# 71                                      NaN                            NaN
# 191                I really liked this one.                            NaN
# 193                                     NaN  Best data cable charging fast
# 223    Good Quality but less Power Delivery                            NaN
# 369                                  Sturdy                            NaN
# ...                                     ...                            ...
# 21862   Good for beginners or minor repairs                            NaN
# 21867                          Good product                            NaN
# 21868                   I like this product                            NaN
# 21877    Cutter speed and power is very low                            NaN
# 21949                          Old is gold.                            NaN
#
#                                                 img_link  \
# 71     https://m.media-amazon.com/images/I/31wOPjcSxl...
# 191    https://m.media-amazon.com/images/W/WEBP_40237...
# 193    https://m.media-amazon.com/images/W/WEBP_40237...
# 223    https://m.media-amazon.com/images/W/WEBP_40237...
# 369    https://m.media-amazon.com/images/W/WEBP_40237...
# ...                                                  ...
# 21862  https://m.media-amazon.com/images/W/WEBP_40237...
# 21867  https://m.media-amazon.com/images/W/WEBP_40237...
# 21868  https://m.media-amazon.com/images/W/WEBP_40237...
# 21877  https://m.media-amazon.com/images/W/WEBP_40237...
# 21949  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                             product_link
# 71     https://www.amazon.in/Solero-TB301-Charging-48...
# 191    https://www.amazon.in/Mi-Braided-USB-Type-C-Ca...
# 193    https://www.amazon.in/Mi-Braided-USB-Type-C-Ca...
# 223    https://www.amazon.in/boAt-A325-Tangle-Free-Ch...
# 369    https://www.amazon.in/Ambrane-Unbreakable-Char...
# ...                                                  ...
# 21862  https://www.amazon.in/akiara-Tailoring-Stitchi...
# 21867  https://www.amazon.in/akiara-Tailoring-Stitchi...
# 21868  https://www.amazon.in/Usha-1212-PTC-Adjustable...
# 21877  https://www.amazon.in/Handheld-Electric-Vegeta...
# 21949  https://www.amazon.in/Havells-Ventilair-230mm-...
#
# [252 rows x 16 columns]

# %%
mask = expand_df['rating_count'].isna()
expand_df.loc[mask,'rating_count'] = '1'

# %%
expand_df['rating_count'] = [row.strip().replace(',','') for row in expand_df['rating_count'].values]

# %%
expand_df['rating_count'] = expand_df['rating_count'].astype(int)

# %%
expand_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11515 entries, 0 to 21960
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           11515 non-null  object
#  1   product_name         11515 non-null  object
#  2   category             11515 non-null  object
#  3   discounted_price     11515 non-null  object
#  4   actual_price         11515 non-null  object
#  5   discount_percentage  11515 non-null  object
#  6   rating               11515 non-null  object
#  7   rating_count         11515 non-null  int64
#  8   about_product        11515 non-null  object
#  9   user_id              11515 non-null  object
#  10  user_name            11515 non-null  object
#  11  review_id            11515 non-null  object
#  12  review_title         11490 non-null  object
#  13  review_content       11282 non-null  object
#  14  img_link             11515 non-null  object
#  15  product_link         11515 non-null  object
# dtypes: int64(1), object(15)
# memory usage: 1.7+ MB

# %%
# Filter multiple missing row
both_review_missing = expand_df[expand_df['review_title'].isna() & expand_df['review_content'].isna()]

# %%
# Filter both contain rows
both_review_contain = expand_df[expand_df['review_title'].notna() & expand_df['review_content'].notna()]
both_review_contain
# Out:
#        product_id                                       product_name  \
# 0      B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1      B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2      B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 3      B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4      B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# ...           ...                                                ...
# 21956  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
# 21957  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
# 21958  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
# 21959  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
# 21960  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                 category discounted_price  \
# 0      Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1      Computers&Accessories|Accessories&Peripherals|...             ₹399
# 2      Computers&Accessories|Accessories&Peripherals|...             ₹399
# 3      Computers&Accessories|Accessories&Peripherals|...             ₹399
# 4      Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...                                                  ...              ...
# 21956  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
# 21957  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
# 21958  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
# 21959  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
# 21960  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
#
#       actual_price discount_percentage rating  rating_count  \
# 0           ₹1,099                 64%    4.2         24269
# 1           ₹1,099                 64%    4.2         24269
# 2           ₹1,099                 64%    4.2         24269
# 3           ₹1,099                 64%    4.2         24269
# 4           ₹1,099                 64%    4.2         24269
# ...            ...                 ...    ...           ...
# 21956       ₹3,690                 22%    4.3          6987
# 21957       ₹3,690                 22%    4.3          6987
# 21958       ₹3,690                 22%    4.3          6987
# 21959       ₹3,690                 22%    4.3          6987
# 21960       ₹3,690                 22%    4.3          6987
#
#                                            about_product  \
# 0      High Compatibility : Compatible With iPhone 12...
# 1      High Compatibility : Compatible With iPhone 12...
# 2      High Compatibility : Compatible With iPhone 12...
# 3      High Compatibility : Compatible With iPhone 12...
# 4      High Compatibility : Compatible With iPhone 12...
# ...                                                  ...
# 21956  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
# 21957  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
# 21958  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
# 21959  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
# 21960  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
#
#                             user_id         user_name       review_id  \
# 0      AG3D6O4STAQKAY2UVGEUV46KN35Q             Manav  R3HXWT0LRP0NMF
# 1      AHMY5CWJMMK5BJRBBSNLYT3ONILA      Adarsh gupta  R2AJM3LFTLZHFO
# 2      AHCTC6ULH4XB6YHDY6PCH2R772LQ           Sundeep    R6AQJGUP6P86
# 3      AGYHHIERNXKA6P5T7CZLXKVPT7IQ    S.Sayeed Ahmed  R1KD19VHEDV0OR
# 4      AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q    jaspreet singh  R3C02RMYQMK6FC
# ...                             ...               ...             ...
# 21956  AHXCDNSXAESERITAFELQABFVNLCA           PARDEEP  R2ZC03S4QXOW4Y
# 21957  AGRZD6CHLCUNOLMMIMIHUCG7PIFA  Anindya Pramanik  R186H8YW34BQD5
# 21958  AFQZVGSOSOJHKFQQMCEI4725QEKQ       Vikas Singh  R10NC3D321N59G
# 21959  AEALVGXXIP46OZVXKRUXSDWZJMEA   Harshada Pimple   REKF75G4SOAOX
# 21960  AGEFL3AY7YXEFZA4ZJU3LP7K7OJQ            Saw a.  R2G0ZT4JQX322I
#
#                                         review_title  \
# 0                                          Satisfied
# 1                            Charging is really fast
# 2                                    Value for money
# 3                                     Product review
# 4                                       Good quality
# ...                                              ...
# 21956                             Excellent product✌
# 21957               A good product for household use
# 21958  मुझे बिल्कुल भी मजा नहीं आया और वापस कर दिया।
# 21959                                   Best product
# 21960                                           Good
#
#                                           review_content  \
# 0         Looks durable Charging is fine tooNo complains
# 1                                Charging is really fast
# 2                                          good product.
# 3                   Till now satisfied with the quality.
# 4      This is a good product . The charging speed is...
# ...                                                  ...
# 21956                               It is a nice product
# 21957   easy to use. The grilling function is also wo...
# 21958                                  Very good product
# 21959           This is a pretty powerful sandwich maker
# 21960               for home use. The product looks good
#
#                                                 img_link  \
# 0      https://m.media-amazon.com/images/W/WEBP_40237...
# 1      https://m.media-amazon.com/images/W/WEBP_40237...
# 2      https://m.media-amazon.com/images/W/WEBP_40237...
# 3      https://m.media-amazon.com/images/W/WEBP_40237...
# 4      https://m.media-amazon.com/images/W/WEBP_40237...
# ...                                                  ...
# 21956  https://m.media-amazon.com/images/W/WEBP_40237...
# 21957  https://m.media-amazon.com/images/W/WEBP_40237...
# 21958  https://m.media-amazon.com/images/W/WEBP_40237...
# 21959  https://m.media-amazon.com/images/W/WEBP_40237...
# 21960  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                             product_link
# 0      https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1      https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 2      https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 3      https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 4      https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# ...                                                  ...
# 21956  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
# 21957  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
# 21958  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
# 21959  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
# 21960  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
#
# [11265 rows x 16 columns]

# %% [markdown]
# ## NLP --> Natural Language Processing
# ### Text Cleaning, Tokenaization & Sentiment Feature

# %%
#valid text row selection
text_df = expand_df[expand_df['review_content'].notna() & expand_df['rating'].notna() & (expand_df['review_content'].str.strip() != "")].copy()

# %%
print(text_df.shape)
print(expand_df.shape)
# Out:
# (11281, 16)
# (11515, 16)

# %%
def rating_to_sentiment(rating):
    if rating>=4:
        return 'positive'
    elif rating<=2:
        return 'negative'
    else:
        return 'neutral'

# %%
text_df['rating'].unique()
# Out:
# array(['4.2', '4.0', '3.9', '4.1', '4.3', '4.4', '4.5', '3.7', '3.3',
#        '3.6', '3.4', '3.8', '3.5', '4.6', '3.2', '5.0', '4.7', '3.0',
#        '2.8', '4', '3.1', '4.8', '2.3', '|', '2', '3', '2.6', '2.9'],
#       dtype=object)

# %%
expand_df['rating'] = expand_df['rating'].replace("|", np.nan)

# %%
expand_df['rating'] = pd.to_numeric(expand_df['rating'], errors='coerce')

# %%
expand_df['rating'] = expand_df.groupby('product_id')['rating']\
    .transform(lambda x: x.fillna(x.mean()))

# %%
expand_df['rating'].isna().sum()
# Out:
# np.int64(8)

# %% [markdown]
# #### Lets drop this negligible rows. Because this are unrecoverable.

# %%
expand_df['rating'] = expand_df['rating'].dropna()

# %%
text_df = expand_df[expand_df['review_content'].notna() & expand_df['rating'].notna() & (expand_df['review_content'].str.strip() != "")].copy()

# %%
print(expand_df.shape)
print(text_df.shape)
# Out:
# (11515, 16)
# (11273, 16)

# %%
text_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11273 entries, 0 to 21960
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           11273 non-null  object
#  1   product_name         11273 non-null  object
#  2   category             11273 non-null  object
#  3   discounted_price     11273 non-null  object
#  4   actual_price         11273 non-null  object
#  5   discount_percentage  11273 non-null  object
#  6   rating               11273 non-null  float64
#  7   rating_count         11273 non-null  int64
#  8   about_product        11273 non-null  object
#  9   user_id              11273 non-null  object
#  10  user_name            11273 non-null  object
#  11  review_id            11273 non-null  object
#  12  review_title         11256 non-null  object
#  13  review_content       11273 non-null  object
#  14  img_link             11273 non-null  object
#  15  product_link         11273 non-null  object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 1.5+ MB

# %%
#add sentiment column to text_df
text_df['sentiment'] = text_df['rating'].apply(rating_to_sentiment)

# %%
text_df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 3  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹399
#
#   actual_price discount_percentage  rating  rating_count  \
# 0       ₹1,099                 64%     4.2         24269
# 1       ₹1,099                 64%     4.2         24269
# 2       ₹1,099                 64%     4.2         24269
# 3       ₹1,099                 64%     4.2         24269
# 4       ₹1,099                 64%     4.2         24269
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  High Compatibility : Compatible With iPhone 12...
# 2  High Compatibility : Compatible With iPhone 12...
# 3  High Compatibility : Compatible With iPhone 12...
# 4  High Compatibility : Compatible With iPhone 12...
#
#                         user_id       user_name       review_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q           Manav  R3HXWT0LRP0NMF
# 1  AHMY5CWJMMK5BJRBBSNLYT3ONILA    Adarsh gupta  R2AJM3LFTLZHFO
# 2  AHCTC6ULH4XB6YHDY6PCH2R772LQ         Sundeep    R6AQJGUP6P86
# 3  AGYHHIERNXKA6P5T7CZLXKVPT7IQ  S.Sayeed Ahmed  R1KD19VHEDV0OR
# 4  AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q  jaspreet singh  R3C02RMYQMK6FC
#
#               review_title                                     review_content  \
# 0                Satisfied     Looks durable Charging is fine tooNo complains
# 1  Charging is really fast                            Charging is really fast
# 2          Value for money                                      good product.
# 3           Product review               Till now satisfied with the quality.
# 4             Good quality  This is a good product . The charging speed is...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/W/WEBP_40237...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link sentiment
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...  positive
# 1  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...  positive
# 2  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...  positive
# 3  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...  positive
# 4  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...  positive

# %% [markdown]
# ## NLP Tokenization pipeline

# %%
text_df['review_content'] = text_df['review_content'].str.lower()

# %%
text_df['review_content']
# Out:
# 0           looks durable charging is fine toono complains
# 1                                  charging is really fast
# 2                                            good product.
# 3                     till now satisfied with the quality.
# 4        this is a good product . the charging speed is...
#                                ...
# 21956                                 it is a nice product
# 21957     easy to use. the grilling function is also wo...
# 21958                                    very good product
# 21959             this is a pretty powerful sandwich maker
# 21960                 for home use. the product looks good
# Name: review_content, Length: 11273, dtype: object

# %% [markdown]
# ## Normalization necessary functions

# %%
import unicodedata
import emoji
import re

def Unicode_normalization(text):
    text = unicodedata.normalize('NFKD', text)
    text = text.encode('ascii', 'ignore').decode('utf-8', 'ignore')

    return text


def emoji_normalization(text):
    return emoji.demojize(text, delimiters=(" ", " "))


def repeated_text_normalize(text):
    return re.sub(r'(.)\1{2.}', r'\1\1', text)


def whitespace_normalization(text):
    return re.sub(r'\s+', ' ', text).strip()

# %%
## pipeline function
def normalize_text(text):
    if pd.notna(text):
        return text
    
    text = Unicode_normalization(text)
    text = emoji_normalization(text)
    text = repeated_text_normalize(text)
    text = whitespace_normalization(text)

    return text

# %%
## applying to dataset

text_df['normalize_review'] = text_df['review_content'].apply(normalize_text)

# %%
text_df.head(3)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹399
#
#   actual_price discount_percentage  rating  rating_count  \
# 0       ₹1,099                 64%     4.2         24269
# 1       ₹1,099                 64%     4.2         24269
# 2       ₹1,099                 64%     4.2         24269
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  High Compatibility : Compatible With iPhone 12...
# 2  High Compatibility : Compatible With iPhone 12...
#
#                         user_id     user_name       review_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q         Manav  R3HXWT0LRP0NMF
# 1  AHMY5CWJMMK5BJRBBSNLYT3ONILA  Adarsh gupta  R2AJM3LFTLZHFO
# 2  AHCTC6ULH4XB6YHDY6PCH2R772LQ       Sundeep    R6AQJGUP6P86
#
#               review_title                                  review_content  \
# 0                Satisfied  looks durable charging is fine toono complains
# 1  Charging is really fast                         charging is really fast
# 2          Value for money                                   good product.
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link sentiment  \
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...  positive
# 1  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...  positive
# 2  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...  positive
#
#                                  normalize_review
# 0  looks durable charging is fine toono complains
# 1                         charging is really fast
# 2                                   good product.

# %% [markdown]
# ## Text Cleaning Process

# %%
def clean_punctuation(text):
    text = re.sub(r"[^\w\s!?]", "", text)
    return text
