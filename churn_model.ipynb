# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
conn=sqlite3.connect('customer_churn.db')
tables=pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)
df=pd.read_sql("SELECT * FROM amazon_customer_dataset", conn)
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %% [markdown]
# ### EDA (Exploratory Data Analysis)
#
# - Data distribution (value distribution)
#
# - Missing values / anomalies

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# data-type change in object to numeric

# %%
numeric_cols = ['discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count']
for col in numeric_cols:
    df[col] = df[col].replace(r'[₹\*,+,%]', '', regex=True)
    df[col]=pd.to_numeric(df[col], errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   int64
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# missing value handle with mean

# %%
df.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 1
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df['rating'] = df['rating'].fillna(df['rating'].mean())
df['rating_count'] = df['rating_count'].fillna(df['rating_count'].mean())
df.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# ### check duplicate value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### The data is cleaned. Now we can start analyzing it to find patterns, trends, and useful insights.
# - **Question:** Which product has the highest number of sales (based on rating_count or reviews)?
# - **Plot:** Box plot of rating_count across products

# %%
top_products = df.sort_values('rating_count', ascending=False).head(10)
plt.figure(figsize=(15,6))
sns.boxplot(data=top_products, x='rating_count', y='product_name')
plt.title('Box Plot of Rating Count for Top 10 Products')
plt.xlabel('Rating Count')
plt.ylabel('Product Name')
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Question:** What is the average spending of a customer?
# - **Plot:** Scatter plot of actual_price vs discounted_price

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='actual_price', y='discounted_price', data=df)
plt.title('Scatter Plot of Actual Price vs Discounted Price')
plt.xlabel('Actual Price')
plt.ylabel('Discounted Price')
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Question:** Which category’s products are more popular or have low ratings?
# - **Plot:** Bar plot of average rating or total rating_count per category

# %%
category_counts = df.groupby('category')['rating_count'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(12,6))
sns.barplot(x=category_counts.values,y=category_counts.index,palette='viridis')
plt.title('Total Rating Count by Category')
plt.xlabel('Total Rating Count')
plt.ylabel('Category')
plt.show()
# Out:
# C:\Users\Ashik\AppData\Local\Temp\ipykernel_27536\1344102175.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.values,y=category_counts.index,palette='viridis')

# %% [markdown]
# total rating_count per category

# %%
low_count_categories = df.groupby('category')['rating'].mean().sort_values().head(15)
plt.figure(figsize=(10,6))
sns.barplot(x=low_count_categories.values, y=low_count_categories.index,palette='magma')
plt.xlabel('Average Rating')
plt.ylabel('Category')
plt.title('Categories with Lowest Average Rating')
plt.show()
# Out:
# C:\Users\Ashik\AppData\Local\Temp\ipykernel_27536\3102519005.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=low_count_categories.values, y=low_count_categories.index,palette='magma')

# %% [markdown]
# Which product or category receives the highest number of positive and negative reviews?

# %%
positive_products=df[df['rating']>4].groupby('product_name').size().sort_values(ascending=False).head(10)
plt.figure(figsize=(12,6))
sns.barplot(x=positive_products.values, y=positive_products.index, palette='coolwarm')
plt.title('Top 10 Products with Highest Number of Positive Ratings (4 and above)')
plt.xlabel('Number of Positive Ratings')    
plt.ylabel('Product Name')
plt.show()
# Out:
# C:\Users\Ashik\AppData\Local\Temp\ipykernel_27536\3607978992.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=positive_products.values, y=positive_products.index, palette='coolwarm')

# %% [markdown]
# Which User Group Is Most Dissatisfied

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['rating_count'], y=df['rating'], hue=df['user_id'], palette='tab10', legend=False)
plt.title('Scatter Plot of Rating Count vs Rating by User')
plt.xlabel('Rating Count')
plt.ylabel('Rating')
plt.legend(title='User', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ashik\AppData\Local\Temp\ipykernel_27536\591984870.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='User', bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# which product is most popular?

# %%
popular_products=df.groupby('category')['rating'].mean().sort_values(ascending=False).head(15)
plt.figure(figsize=(12,6))
sns.barplot(x=popular_products.values, y=popular_products.index, palette='Blues_d')
plt.title('Top 10 Categories with Highest Average Ratings')
plt.xlabel('Average Rating')
plt.ylabel('Category')
plt.show()
# Out:
# C:\Users\Ashik\AppData\Local\Temp\ipykernel_27536\2078924958.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=popular_products.values, y=popular_products.index, palette='Blues_d')
